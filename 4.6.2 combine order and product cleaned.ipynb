# %%
import pandas as pd
import numpy as np
import os

# %%
# import orders product combined pikle file
df_ords_prod_comb = pd.read_pickle(r'C:\Users\User\Documents\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
df_ords_prod_comb.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True         196
# 1                  8                     NaN         True       14084
# 2                  8                     NaN         True       12427
# 3                  8                     NaN         True       26088
# 4                  8                     NaN         True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_ords_prod_comb.shape
# Out:
# (32434489, 12)

# %%
path = r'C:\Users\User\Documents\Instacart Basket Analysis'

# %%
df_prod_check = pd.read_csv(r'C:\Users\User\Documents\Instacart Basket Analysis\02 Data\Prepared Data\products_checked.csv', index_col = False)

# %%
df_prod_check = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prod_check.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prod_check.tail()
# Out:
#        product_id                                product_name  aisle_id  \
# 49667       49684   Vodka, Triple Distilled, Twist of Vanilla       124
# 49668       49685          En Croute Roast Hazelnut Cranberry        42
# 49669       49686                            Artisan Baguette       112
# 49670       49687  Smartblend Healthy Metabolism Dry Cat Food        41
# 49671       49688                      Fresh Foaming Cleanser        73
#
#        department_id  prices
# 49667              5     5.3
# 49668              1     3.1
# 49669              3     7.8
# 49670              8     4.7
# 49671             11    13.5

# %%
df_prod_check.shape
# Out:
# (49672, 5)

# %%
#Drop unnamed columns in df_ords_combined
df_ords_prod_comb = df_ords_prod_comb.drop(columns = ['Unnamed: 0', '_merge'])

# %%
# Merge df_prod_check and df_ords_prod_comb
df_merged = df_prod_check.merge(df_ords_prod_comb, on = 'product_id', indicator = True)

# %%
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %%
# confirm the result of the merge flag
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#Export orders_products_merged file
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
