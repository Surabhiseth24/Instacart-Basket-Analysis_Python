# %%
import pandas as pd
import numpy as np
import os

# %%
# import orders product merged pikle file
ords_prods_merge = pd.read_pickle(r'C:\Users\User\Documents\Instacart Basket Analysis\02 Data\Prepared Data\df_ords_prods_merge_updated.pkl')

# %%
path = r'C:\Users\User\Documents\Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_prods_merge_updated.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
ords_prods_merge.groupby('product_name')

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %% [markdown]
# working on the entire data frame there are 21 deptt_ids compared to 1000000 data where only 8 deptt. ids

# %%
# step 4
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18888\1146889979.py:2: FutureWarning: The provided callable <function max at 0x000002225C5096C0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %%
# creating a loyalty flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...

# %%
# step 5 identify spending habits of different types of customers by calculating mean, minimum and maximum of each loyalty flag
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
# step 6 creating column for average spender
ords_prods_merge['average_spend'] = ords_prods_merge.groupby(['user_id']) ['prices'].transform(np.mean)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18888\3502417023.py:2: FutureWarning: The provided callable <function mean at 0x000002225C50A0C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_spend'] = ords_prods_merge.groupby(['user_id']) ['prices'].transform(np.mean)

# %%
# creating flag for low and high spender
ords_prods_merge.loc[ords_prods_merge['average_spend'] < 10, 'spender_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_spend'] >= 10, 'spender_flag'] = 'High spender'

# %%
# check results
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'average_spend', 'spender_flag', 'prices']].tail(50)
# Out:
#           user_id  average_spend  spender_flag  prices
# 32404809   111542       7.615238   Low spender    13.5
# 32404810   114963     397.793370  High spender    13.5
# 32404811   118871       7.241190   Low spender    13.5
# 32404812   121646      10.022764  High spender    13.5
# 32404813   124944       8.400000   Low spender    13.5
# 32404814   128148       7.705316   Low spender    13.5
# 32404815   128148       7.705316   Low spender    13.5
# 32404816   128930       7.524390   Low spender    13.5
# 32404817   128930       7.524390   Low spender    13.5
# 32404818   129901       8.694872   Low spender    13.5
# 32404819   142639       9.872881   Low spender    13.5
# 32404820   144914       8.062232   Low spender    13.5
# 32404821   145111       8.177328   Low spender    13.5
# 32404822   145526      76.089009  High spender    13.5
# 32404823   145732       7.681667   Low spender    13.5
# 32404824   146323       8.740690   Low spender    13.5
# ...

# %%
# step 7 create a column for frequent users
ords_prods_merge['customer_frequency'] = ords_prods_merge.groupby(['user_id']) ['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18888\2891569367.py:2: FutureWarning: The provided callable <function median at 0x000002225C634B80> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['customer_frequency'] = ords_prods_merge.groupby(['user_id']) ['days_since_prior_order'].transform(np.median)

# %%
# creating flag on order frequency
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['customer_frequency'] > 10) & (ords_prods_merge['customer_frequency'] <= 20 ), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# check results
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'days_since_prior_order', 'customer_frequency', 'frequency_flag']].head(20)
# Out:
#     user_id  days_since_prior_order  customer_frequency     frequency_flag
# 0       138                     3.0                 8.0  Frequent customer
# 1       138                    20.0                 8.0  Frequent customer
# 2       709                     6.0                 8.0  Frequent customer
# 3       764                     NaN                 9.0  Frequent customer
# 4       764                     9.0                 9.0  Frequent customer
# 5       777                    26.0                11.0   Regular customer
# 6       825                    30.0                20.0   Regular customer
# 7       910                    30.0                 6.0  Frequent customer
# 8      1052                    19.0                10.0  Frequent customer
# 9      1052                    15.0                10.0  Frequent customer
# 10     1379                     NaN                20.0   Regular customer
# ...

# %%
# step 9 export data frame
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_aggregated.pkl'))
